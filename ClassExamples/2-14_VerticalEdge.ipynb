# %%
import cv2
import numpy as np
import urllib.request
import matplotlib.pyplot as plt

url = 'https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png'
with urllib.request.urlopen(url) as url_response:
    img_array = np.array(bytearray(url_response.read()), dtype=np.uint8)
    img = cv2.imdecode(img_array, cv2.IMREAD_GRAYSCALE)

#  vertical edge detection filter
filter = np.array([[-1, 0, 1],
                   [-2, 0, 2],
                   [-1, 0, 1]])


edges = cv2.filter2D(img, -1, filter)


fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(filter, cmap='gray')
axs[0].set_title('Vertical Edge Detection Filter')
axs[1].imshow(edges, cmap='gray')
axs[1].set_title('Filtered Image')
plt.show()


fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].imshow(img, cmap='gray')
axs[0].set_title('Original Image')
axs[1].imshow(filter, cmap='gray')
axs[1].set_title('Vertical Edge Detection Filter')
axs[2].imshow(edges, cmap='gray')
axs[2].set_title('Filtered Image')
plt.show()

# %%
import cv2
import numpy as np
import urllib.request
import matplotlib.pyplot as plt

url = 'https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png'
with urllib.request.urlopen(url) as url_response:
    img_array = np.array(bytearray(url_response.read()), dtype=np.uint8)
    img = cv2.imdecode(img_array, cv2.IMREAD_GRAYSCALE)

filter = np.array([[-1, -2, -1],
                   [0, 0, 0],
                   [1, 2, 1]])


edges = cv2.filter2D(img, -1, filter)


fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(filter, cmap='gray')
axs[0].set_title('Horizontal Edge Detection Filter')
axs[1].imshow(edges, cmap='gray')
axs[1].set_title('Filtered Image')
plt.show()


fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].imshow(img, cmap='gray')
axs[0].set_title('Original Image')
axs[1].imshow(filter, cmap='gray')
axs[1].set_title('Horizontal Edge Detection Filter')
axs[2].imshow(edges, cmap='gray')
axs[2].set_title('Filtered Image')
plt.show()
